# %%
import sympy as sp

# %%
d = sp.symbols('d', cls=sp.IndexedBase)
i, two = sp.symbols('i, 2')
E, d_mean, n_mean = sp.symbols('\\bar{E} \\bar{d} \delta_n')
#Sd = (sp.summation((d[i] - d_mean)**2) / 6 - 1)**(1/2)
fmap = {
    d:{0:1,1:2,2:3},
    two:2,
}
f = sp.summation((d[i] - E)**2, (i, 0, two))
(d[i]).subs(fmap)
# Out:
# 3
